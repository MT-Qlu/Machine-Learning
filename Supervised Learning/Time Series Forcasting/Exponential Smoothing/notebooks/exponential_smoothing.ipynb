# %% [markdown]
# # Exponential Smoothing Notebook
#
# Mirror the Holt-Winters training pipeline, inspect components, and evaluate forecast accuracy.

# %%
"""Bootstrap the notebook environment."""
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd
import matplotlib.pyplot as plt
from IPython.display import display

from src.config import CONFIG as ES_CONFIG, ExponentialSmoothingConfig
from src.data import load_dataframe, train_test_split
from src.pipeline import AirPassengersExponentialSmoothingPipeline

# %%
config: ExponentialSmoothingConfig = ES_CONFIG
df = load_dataframe(config)
display(df.head())
df.plot(y=config.target_column, figsize=(10, 4), title='AirPassengers')
plt.show()

# %%
train_series, test_series = train_test_split(config)
pipeline = AirPassengersExponentialSmoothingPipeline(config)
metrics = pipeline.train()
metrics

# %%
forecast = pipeline.forecast(len(test_series))
ax = train_series.plot(label='Train', figsize=(10, 4))
test_series.plot(ax=ax, label='Test')
forecast.plot(ax=ax, label='Forecast')
ax.legend()
plt.show()
