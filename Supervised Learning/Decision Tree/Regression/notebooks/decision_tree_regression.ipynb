# %% [markdown]
# # California Housing Decision Tree Regression
#
# Replicate the training pipeline, evaluate R²/RMSE/MAE, and rank feature importances.

# %%
"""Bootstrap notebook imports and project path."""
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().resolve().parent
if str(PROJECT_ROOT) not in sys.path:
    sys.path.append(str(PROJECT_ROOT))

import pandas as pd
from IPython.display import display

from src.config import CONFIG as TREE_CONFIG
from src.data import load_dataset
from src.pipeline import CaliforniaDecisionTreePipeline

# %%
df = load_dataset(TREE_CONFIG)
display(df.head())
df.describe().T

# %%
pipeline = CaliforniaDecisionTreePipeline(TREE_CONFIG)
metrics = pipeline.train()
pipeline.save()
pipeline.write_metrics(metrics)
metrics

# %%
regressor = pipeline.pipeline.named_steps['regressor']
importances = pd.Series(regressor.feature_importances_, index=TREE_CONFIG.feature_columns)
importances.sort_values(ascending=False)
