# %% [markdown]
# # PyTorch CNN — Fashion-MNIST
#
# End-to-end walkthrough using the modular PyTorch package located in `../src`.

# %% [markdown]
# **Workflow**
#
# 1. Configure paths and imports.
# 2. Trigger training via `train.train()` (auto-selects `mps`/`cuda`/`cpu`).
# 3. Inspect metrics and run a quick inference sample.

# %%
from pathlib import Path
import sys

NOTEBOOK_DIR = Path().resolve()
SRC_DIR = NOTEBOOK_DIR.parent / 'src'
if str(SRC_DIR) not in sys.path:
    sys.path.append(str(SRC_DIR))

from config import CONFIG  # noqa: E402
from inference import load_model, predict  # noqa: E402
from train import train  # noqa: E402

CONFIG

# %%
metrics = train(CONFIG)
metrics

# %%
import torch
from torchvision import datasets, transforms

transform = transforms.Compose([transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))])
sample_ds = datasets.FashionMNIST(root=str(CONFIG.data_dir), train=False, download=True, transform=transform)
image, label = sample_ds[0]
model = load_model(config=CONFIG)
prediction = predict([image], model=model, config=CONFIG)[0]
label, prediction
